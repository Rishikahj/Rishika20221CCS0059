# %%
import pandas as pd
import matplotlib.pyplot as plt
data={
    "Date":pd.to_datetime(["2022-01-01","2022-02-02","2022-03-02","2022-04-03","2023-01-04","2023-03-05","2023-04-01","2023-05-03","2023-06-01"]),
    "Value":[10, 15, 28, 35, 42, 48, 58, 65, 75]
}
df=pd.DataFrame(data)
df.set_index("Date",inplace=True)
plt.figure(figsize=(10,6))
plt.plot(df.index,df["Value"],marker='X')
plt.xlabel("Date")
plt.ylabel("Value")
plt.title("Time series with trend")
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
data={
    "Date":pd.to_datetime(["2022-01-01","2022-02-02","2022-03-02","2022-04-03","2022-05-04","2023-01-01","2023-02-06","2023-03-03","2023-04-03"]),
    "Value":[10, 58, 28, 96, 58, 28, 58, 65, 20]
}
df=pd.DataFrame(data)
df.set_index("Date",inplace=True)
plt.figure(figsize=(10,6))
plt.plot(df.index,df["Value"],marker='X')
plt.xlabel("Date")
plt.ylabel("Value")
plt.title("Time series with trend")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter

text_data="Python is the high-level, general-purpose programming language.Its design philosophy emphasizes code readability with the use of significant indentation"
Wordcloud=WordCloud(width=800,height=400,background_color='lavender').generate(text_data)
plt.figure(figsize=(10,5))
plt.imshow(Wordcloud)
plt.title('Word Cloud')
plt.show()
words=text_data.split()
word_counts=Counter(words)
plt.figure(figsize=(10,5))
plt.bar(word_counts.keys(),word_counts.values())
plt.title('Histogram of word frequencies')
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.xticks(rotation=90)
plt.show()
